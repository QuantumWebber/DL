# %% [markdown]
# ![image.png](attachment:e394f1b5-6754-4b24-b95e-5addc646ba8b.png)

# %% [markdown]
# ![image.png](attachment:8391cf85-7b9b-4560-9c1b-260deaead11a.png)

# %% [markdown]
# <h2>Model Summary</h2>

# %% [markdown]
# ![image.png](attachment:afdfe4d0-d134-472e-9ad6-9a652b37b899.png)
