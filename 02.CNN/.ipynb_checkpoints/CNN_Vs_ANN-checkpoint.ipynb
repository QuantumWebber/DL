# %% [markdown]
# ![image.png](attachment:b11275bc-7533-4641-bb42-3ddeb862d285.png)

# %% [markdown]
# ![image.png](attachment:fa74ce48-d8d0-4414-b007-6a9c24806078.png)

# %% [markdown]
# ![image.png](attachment:e973ccab-a9ad-444c-ae3a-5a36278c04c5.png)

# %%
# trainable parameters of cnn do not depend on image size so it is cost effective and reduce complexity while in ann the traninble parameters depend on input size and it may reach in billions
