# %% [markdown]
# ![image.png](attachment:f5031c7f-6468-462f-a390-92986cf10586.png)

# %% [markdown]
# <h1>Cat experiment</h1>
#
# ![image.png](attachment:4b968f63-f47f-4912-8090-59c440699dd8.png)

# %% [markdown]
# <h1>Conclusion</h1>
#
# ![image.png](attachment:854f9106-9aec-40bd-aee0-187ba7b4b71f.png)
#
# ![image.png](attachment:a996bdb5-d23c-4a3c-ad5e-81e1ffeabe62.png)
