# %% [markdown]
# <h2>Basics of Images</h2>
#
# ![image.png](attachment:4f38c364-eafc-4874-8c34-9bae4875dd79.png)
#
# ![image.png](attachment:60daa3be-1828-4075-b968-84cdd9d2aaf6.png)

# %% [markdown]
# <h2>Edge Detection</h2>
#
# ![image.png](attachment:56546e9a-57d4-41ab-8cc1-86e77bd88b90.png)

# %%
# we sometimes use relu after convulation so red remains red (beacuse red represent postitive activation)
#output :
# if input is n*n and m*m then output is n-m+1*n-m+1

# %% [markdown]
# ![image.png](attachment:9b1ae7bb-0930-4049-a569-385f667cdd26.png)

# %%
#4*4 to theek 2 hai no of filters used
