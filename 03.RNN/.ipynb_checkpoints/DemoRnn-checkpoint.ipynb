# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
# Input shape is (timesteps, features) -> (4, 5)
model=Sequential()
model.add(SimpleRNN(3, input_shape=(4, 5))) 

model.add(Dense(1, activation='sigmoid'))


model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)             │ (None, 3)                   │              27 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)




print("Contents of the first weight matrix (input kernel):")
print(model.get_weights()[0])
# Out:
# (5, 3)
# Contents of the first weight matrix (input kernel):
# [[-0.81388116  0.53133625 -0.15032339]
#  [-0.01107645  0.22585148  0.0463441 ]
#  [-0.45729205 -0.4112798  -0.61374986]
#  [-0.24756598 -0.05800569 -0.31920034]
#  [ 0.8216662   0.49566382  0.854793  ]]

# %%
print(model.get_weights()[1].shape)




print("Contents of the second weight matrix (input kernel):")
print(model.get_weights()[1])
# Out:
# (3, 3)
# Contents of the second weight matrix (input kernel):
# [[ 0.3391328  -0.70349145 -0.62457067]
#  [ 0.94065666  0.24482998  0.23499632]
#  [-0.01240433 -0.6672016   0.74477386]]

# %%
print(model.get_weights()[3].shape)





print(model.get_weights()[3])
# Out:
# (3, 1)
# [[ 0.58071303]
#  [ 0.7872158 ]
#  [-1.1809943 ]]

# %%
print(model.get_weights()[4].shape)
print(model.get_weights()[4])
# Out:
# (1,)
# [0.]
