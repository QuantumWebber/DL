# %% [markdown]
# https://colab.research.google.com/drive/1c4eN4cPxajCpFG6yr1mAUi3sV1JaGLDY?usp=sharing

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense,LSTM,GRU

# %%
# Load the IMDb dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Pad sequences to have the same length
x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %% [markdown]
# ![image.png](attachment:fe3cba36-9605-48b8-8d7a-e9e95d52a96f.png)

# %% [markdown]
# ![image.png](attachment:9be5afad-ca2f-496a-989f-cfb49a8cffca.png)

# %% [markdown]
# ![image.png](attachment:51f50b52-cb47-4ff0-8475-5938c8e8278e.png)

# %%
# # Compile the model
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# # Train the model
# history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
