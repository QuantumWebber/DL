# %% [markdown]
# https://colab.research.google.com/drive/13j607xg4nmVoovln31O4pDNlqCEK3GZ8?usp=sharing

# %%
# the above is approach one

# %% [markdown]
# ![image.png](attachment:85abc638-0a37-403b-8d2a-670d0162c255.png)

# %% [markdown]
# ![image.png](attachment:3a16b982-fd61-476a-8a64-aafd54759363.png)

# %% [markdown]
# <h1>Represntation of review</h1>
# ![image.png](attachment:8cc90646-7b82-4712-9d4c-0c93b7610801.png)

# %% [markdown]
# ![image.png](attachment:847adfa0-e9e4-4bd3-a0ef-2d18de7bdaf0.png)
