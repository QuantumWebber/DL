# %%
#activation function is mathematical gate

# %%
#why activation function is used 
#it is used beacuse without it classification and regression is linear for non linear data and to get better results for classification and regression we use activation function

# %% [markdown]
# ![image.png](attachment:39ec7b38-d59e-45e6-89b1-a4314b4013ab.png)

# %% [markdown]
# ![image.png](attachment:cbeee984-dccb-4ad4-bb3c-328903824bed.png)

# %%
#sigmoid already cover

# %%
#dekho pehli samasya boht asan samajne ke liye ki saturating fucntion to back propogation me gd niklte huye peeche wali layer pr jaayega to choota hota 
# rhega aur vanishing gradient problem aa jaayegi 



# second problem is non zero centred i.e hamre output jo aate activation se wo normalized nhi hote aur agr isko mathematically dekhu to 
#ye samaj aata ki ya to weight ki value ek saath positive ho sakti ya ek saath negative to mei weights ko kuch ko +ve rakhke aur kuch ko -ve rakhke 
# weight ase adjust nhi kr sakta ki loss fucntion minimize ho jaaye


#sigmoid is computally expensive

# %% [markdown]
# ![image.png](attachment:27898f28-5979-4814-a32d-d6a1388a15a5.png)

# %% [markdown]
# ![image.png](attachment:f7a0a13d-cac5-4e16-a7b3-5561894c85b6.png)

# %%
#this function is zero centered

# %% [markdown]
# <h2>Relu</h2>

# %% [markdown]
# ![image.png](attachment:08607374-4b4c-4137-b472-6db3941809a4.png)

# %% [markdown]
# ![image.png](attachment:76ad6aad-8721-4423-bf00-5153d2791849.png)

# %% [markdown]
# <h2>Problem with Relu: Dying Relu Problem</h2>

# %% [markdown]
# ![image.png](attachment:70804cbf-cd80-476d-b7da-f87605e39446.png)
# <p>Dying relu problem me ye hota ki humra agr neuron dead ho yani ki output 0 dera ho aur ase 50% ya usse zada neuron ho to usse dying relu problem kehte uss case mei hamra neural network data ke pattern ko aache se classify nhi kr paayega</p>

# %% [markdown]
# ![image.png](attachment:9db3da5f-7f0d-4051-aca7-368008340f9a.png)
#
#
# <p>Why dying relu problem </p>
# <p>This is beacuse if Z1 is -ve and why it is negative</p>
# <li> If learning rate very high</li>
# <li>High negative bias</li>

# %% [markdown]
# <p>Solutions:</p>
# <li>High Learning Rate</li>
# <li>High positive bias</li>
# <li>Use different Relu</li>

# %% [markdown]
# ![image.png](attachment:ae66fea8-6568-4846-bfca-85ef11ff44da.png)

# %% [markdown]
# ![image.png](attachment:0e3258f8-ae8b-489d-9091-27d424b893b1.png)

# %%
#iska benefit ye hota ki derivate less than 0 ke liye bhi value 0.01 aati to system me chota gradient flow krta rehta

# %% [markdown]
# <li>Unbounded
# <li>Easily computable
# <li> closely zero centered

# %% [markdown]
# ![image.png](attachment:02653db1-2088-441c-814b-139557a464e8.png)

# %% [markdown]
# ![image.png](attachment:1b5187f9-4221-43e4-9121-c67cde1ffcf1.png)

# %% [markdown]
# <li>advantage better than in efficency of relu
# <li>always differentiable

# %% [markdown]
# ![image.png](attachment:3cd25d51-7aae-479e-87f9-6847846cb268.png)

# %% [markdown]
# ![image.png](attachment:4cafce70-bf81-4167-8e34-b5be34f5f476.png)

# %%
#selu is self normalizing 
#mean=0, var=1
