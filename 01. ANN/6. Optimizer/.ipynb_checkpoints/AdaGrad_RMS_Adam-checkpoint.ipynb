# %% [markdown]
# ![image.png](attachment:b15e1aaf-aa33-42f4-a183-e239e0919dd0.png)

# %% [markdown]
# <h1>Elongated bowl problem </h1>

# %% [markdown]
# ![image.png](attachment:15e6f4a1-168c-4354-9c5e-216845f5c38f.png)

# %% [markdown]
# ![image.png](attachment:0d3f409a-f7c8-4386-9b3b-c9fcb9727b31.png)

# %% [markdown]
# <h2>Reason: why batch gradient descent do not work on elongated bowl </h2>

# %% [markdown]
# ![image.png](attachment:0009a077-a2f9-4183-b7c3-99c4b674cf9f.png)

# %% [markdown]
# ![image.png](attachment:1ab759e1-829c-4913-806d-d03aa3904289.png)

# %% [markdown]
# <h1>RmsProp</h1>

# %% [markdown]
# ![image.png](attachment:ec223379-81f9-42ac-8e3f-cff1214f3719.png)

# %%
#sare gradent nhi lere ab recent gradient ko zada value dere purane ko kaam dere

# %% [markdown]
# ![image.png](attachment:e76e65cf-1aa0-44b9-8b91-ee49267db65c.png)

# %% [markdown]
# <h1>Adam </h1>

# %% [markdown]
# ![image.png](attachment:3f1354c6-9ee8-4bac-8759-c0f8aae26007.png)

# %% [markdown]
# ![image.png](attachment:6ddc16a5-74cf-4dff-a592-8307693aa41c.png)
