# %% [markdown]
# <h1>Batch Gradient Descent </h1>

# %% [markdown]
# ![image.png](attachment:2f05d6c4-8e85-4a80-990a-1135c51f8374.png)

# %% [markdown]
# ![image.png](attachment:140e4a24-9783-4ab3-afd5-284a6179fef0.png)

# %% [markdown]
# <h1>Stocastic Gradient Descent</h1>

# %% [markdown]
# ![image.png](attachment:068e9907-c605-46c9-a719-813470f82a07.png)

# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
# !pip install tensorflow
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
# import tensorflow as tf
# from tensorflow import keras
# from keras import Sequential
# from keras.layers import Dense

# %%
# model = Sequential()

# model.add(Dense(10,activation='relu',input_dim=2))
# model.add(Dense(10,activation='relu'))
# model.add(Dense(1,activation='sigmoid'))

# %%
# model.compile(loss='binary_crossentropy',metrics=['accuracy'])
# #start = time.time()
# history = model.fit(X_scaled,y,epochs=500,batch_size=1,validation_split=0.2) #batch size agr 1 rakha to stochastic gd vrna agr 320 hi rakh deta to batch gd hota 
# #print(time.time() - start)

# %%
#batch gd is faster than stochastic gd

# %% [markdown]
# <p>which gd whill converge faster???</p>

# %%
#for same number of epochs convergence of stocastic is fasteer

# %%
#stocastic

# %% [markdown]
# ![image.png](attachment:8ddb804c-ea3d-48ba-a6f2-ac6a9cbf5aa1.png)

# %%
#batch

# %% [markdown]
# ![image.png](attachment:298a599e-ed98-4971-85cb-0e9fb71a77a6.png)

# %% [markdown]
# ![image.png](attachment:5d4607d1-367a-4cd9-86fd-c4b1f036667f.png)

# %%
#sgd is better if loss function has local minima so random behaviour help to converge to global minima

# %% [markdown]
# <h1>Vectorization</h1>

# %%
#use of dot product rather than using loop father than loop and optimized

# %% [markdown]
# <h1>Mini Batch Gradient Desecent</h1>

# %% [markdown]
# ![image.png](attachment:887f2899-4cc2-4c30-854c-0aaf04fdb0b4.png)

# %%
#why batch size is multiple of 2 
#ans- ram architecture aache se use hota

# %% [markdown]
# ![image.png](attachment:8f47a116-84b8-4def-b554-39a9643f01be.png)
