# %% [markdown]
# <li>Hidden Layers</li>
# <li>Neuron per Layer</li>
# <li>Learning Rate</li>
# <li>Optimizer</li>
# <li>Batch Size</li>
# <li>Activation Function</li>
# <li>Epochs</li>

# %% [markdown]
# <strong>More no of layers represent more better representation learning thus means features are extracted more properly
# <li>we can make hidden layer till overfiiting doesnt happen</li>

# %% [markdown]
# <strong>Previously number of neuron per layer follow pyramidal structure
# <li>But now it is proveen that we can take equal neuron in each layer also</li>
# <li>Nodes must be sufficent </li>

# %% [markdown]
# ![image.png](attachment:7e72b836-f86d-4db7-9f30-46f3dfbc51ac.png)

# %% [markdown]
# <strong> no of epochs depnds on early stopping

# %% [markdown]
# ![image.png](attachment:674e3264-2165-4e75-b388-a335add1866b.png)

# %% [markdown]
# <h4>Early Stopping</h4>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\Jatin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 7s 754us/step

# %%
#shi no of epochs nhi model overfit kr rha

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, callbacks=callback)
# Out:
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5039 - loss: 0.6950 - val_accuracy: 0.5500 - val_loss: 0.6942
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4445 - loss: 0.6943 - val_accuracy: 0.4000 - val_loss: 0.6966
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4961 - loss: 0.6926 - val_accuracy: 0.3000 - val_loss: 0.6996
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5242 - loss: 0.6901 - val_accuracy: 0.3000 - val_loss: 0.7021
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5500 - loss: 0.6880 - val_accuracy: 0.4000 - val_loss: 0.7046
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5359 - loss: 0.6878 - val_accuracy: 0.4000 - val_loss: 0.7073
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5578 - loss: 0.6849 - val_accuracy: 0.4000 - val_loss: 0.7098
# Epoch 8/500
# ...

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 8s 840us/step

# %% [markdown]
# ![image.png](attachment:4cadbbd4-7a3b-4320-99c6-b6ee82a2d147.png)
