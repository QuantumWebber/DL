# %% [markdown]
# ![image.png](attachment:f61d0944-f273-473c-b0ca-66c5315542e4.png)

# %% [markdown]
# ![image.png](attachment:66d3e8b9-8f53-490b-82a3-3d222a0a3812.png)

# %%
#hum yha derivate hi kyu krte kyoki derivative rate of change btata ya slope btata jab hum derivative at a point ki baat krte iska simple mtlb bas ye ki derivative nikle se hume W and B ke ye pta lg rha ki Loss pr kitna change aa rha bas

# %%
# baki i guess you already know concept of minima through derivative 
# yr minima ka yha kya kaam bas ye kaam ki ye sab bakchodi hum kr to isliye rhe taki weight aur bias ki value shi aaye minimum loss ke liye

# %%
# so derivate nikl ke inki value 0 rakhde to weight and loss ki value nikl jaaygei

# %% [markdown]
# ![image.png](attachment:a200e018-1b6c-4d8c-b4d2-53ef98aecc09.png)

# %%
# ye boht kuch btara backpropogation ke baare me kse hamra bas negative gradient ke sign se hi hamre weight aur bias kam zada hote yha hamne assumption lia ki b21 ko chd ke saare constant hai to loss b21 ka function hai bas

# %%
# ab graphically dekho to b ki value ko kam zada krke mimum pr pochna

# %%
# learning rate to chalo example me hamne assumption maan lia but sawal yhi iska impact kya hota ???
# sirf yhi hota for example bias aur derivate ki value me hrr baar boht ka farak aara to bias zigzag krega kaafi zada jo aachi cheez nhi 
# usko balance krne ke liye learnig rate aata

# %% [markdown]
# ![image.png](attachment:9d34c479-ebb0-4188-a92c-638cdaff72a1.png)

# %%
# next sawal hum apna backprogation algo epoch pr chlte but epoch kitne rakhe guru jawab hai depend on convergence

# %%
#converge yani kab tak chlo jab tak minima tak na poch jaao
